# %% [markdown]
# # Epigenetics Project — Exploratory Analysis
#
# **Research question:** Consistency of lifestyle-associated DNA methylation
# changes at BDNF, NR3C1, and FKBP5 across intervention types.
#
# **Status:** Phase 2 — data collection in progress

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load dataset
df = pd.read_csv('../data/methylation_dataset.csv')
print(f'Dataset loaded: {len(df)} studies')
df.head()
print(f'Dataset loaded: {len(df)} studies')
df
# Out:
# Dataset loaded: 50 studies
# Dataset loaded: 50 studies
#                  study_id   gene  \
# 0          Yehuda_2015_F0  FKBP5
# 1          Yehuda_2015_F1  FKBP5
# 2            McGowan_2009  NR3C1
# 3           Nothling_2025  FKBP5
# 4          Peng_2018_BDNF   BDNF
# 5         Peng_2018_NR3C1  NR3C1
# 6                Lee_2022   BDNF
# 7             Stroud_2024  NR3C1
# 8             Stroud_2024  FKBP5
# 9     Efstathopoulos_2018  NR3C1
# 10    Efstathopoulos_2018  NR3C1
# 11             Jones_2025  NR3C1
# 12             Jones_2025  FKBP5
# 13              Oren_2025  FKBP5
# 14              Oren_2025  NR3C1
# 15             Wiley_2023  FKBP5
# 16             Wiley_2023  FKBP5
# 17  daSilvaRodrigues_2024   BDNF
# 18  daSilvaRodrigues_2024   BDNF
# 19  daSilvaRodrigues_2024   BDNF
# 20               Cho_2025   BDNF
# 21               Cho_2025   BDNF
# 22               Cho_2025   BDNF
# 23               Cho_2025   BDNF
# 24            Santos_2018  NR3C1
# 25            Santos_2018   BDNF
# 26            Santos_2018  FKBP5
# 27             Moser_2015   BDNF
# 28        Saadatmand_2022  NR3C1
# 29        Saadatmand_2022  FKBP5
# 30          Griffith_2025  NR3C1
# 31            Bierer_2020  FKBP5
# 32             Tyrka_2015  FKBP5
# 33         Grossmann_2024  FKBP5
# 34           Shields_2016  NR3C1
# 35           Bakusic_2021  NR3C1
# 36           Bakusic_2021  NR3C1
# 37            Hummel_2022  NR3C1
# 38            Hummel_2022  FKBP5
# 39              Yang_2025  FKBP5
# 40              Yang_2025  FKBP5
# 41              Yang_2025  FKBP5
# 42              Yang_2025  FKBP5
# 43           Willmer_2022  FKBP5
# 44           Willmer_2022  FKBP5
# 45           Willmer_2022  FKBP5
# 46           Willmer_2022  FKBP5
# 47           Willmer_2022  FKBP5
# 48            Voisey_2019   BDNF
# 49            Voisey_2019   BDNF
#
#                                            cpg_region intervention_type  \
# 0                                  intron7_bin3_site6            stress
# 1                                  intron7_bin3_site6            stress
# 2                                     exon1F_promoter            stress
# 3                                   intron7_CpG1-CpG5            stress
# 4                               promoter_CpG_multiple            stress
# 5                               promoter_CpG_multiple            stress
# 6       Promoter I (CpG1-4, -694 to -654 rel. exon I)            stress
# 7   Promoter exon 1F (13 CpG sites, human homolog ...            stress
# 8             Intron 7 regulatory region (CpG1, CpG2)            stress
# 9             exon 1F CpG2 (near NGFI-A binding site)            stress
# 10            exon 1F CpG2 (near NGFI-A binding site)            stress
# 11  cg06613263 (gene body, North Shore region, ~2k...            stress
# 12  26 CpG sites across gene region (450K/EPIC ove...            stress
# 13                             cg08915438 (TC21 site)            stress
# 14                             cg21979215 (BC21 site)            stress
# 15  CpG site 1 (exact position not detailed in ext...            stress
# 16  CpG site 2 (exact position not detailed in ext...            stress
# 17                      cg12021170 (TSS1500; opensea)          exercise
# 18                         cg08760147 (Body; opensea)          exercise
# 19                        cg11241206 (TSS1500; shore)          exercise
# 20                                         cg05189570          exercise
# 21                                         cg08362738          exercise
# 22                                         cg12067298          exercise
# 23                                         cg20340655          exercise
# 24                        exon 1F promoter, CpG1-CpG2            stress
# 25                             promoter IV, CpG5-CpG7            stress
# 26                                     intron 7, CpG1            stress
# 27  promoter/exon IV, CpG3 (mean of 4 CpGs also re...            stress
# 28  promoter region, ~0.5kb from TSS (chr5:143,404...            stress
# 29  chr6:35,558,486-35,558,567 (overlaps the intro...            stress
# 30         exon 1F, CpG17 and CpG31 (of 31 CpG sites)            stress
# 31  intron 7, site 6 (mean of sites 3-6 also repor...            stress
# 32  intron 7, CpG1 (chr6:35558488) and CpG2 (chr6:...            stress
# 33  34 variable CpGs across the entire FKBP5 locus...            stress
# 34  CpG island shore, proximal promoter (chr5:1434...            stress
# 35  CpG21, amplicon 1 (NGFI-A binding site, NR3C1 ...            stress
# 36  CpG30, amplicon 3 (NGFI-A binding site, NR3C1 ...            stress
# 37                                   promoter exon 1F            stress
# 38                                  intron 7 (5 CpGs)            stress
# 39                                         cg22363520          exercise
# 40                                         cg22363520          exercise
# 41                                         cg00862770          exercise
# 42                                         cg00862770          exercise
# 43               intron 7, CpG542 (137847bp from TSS)          exercise
# 44               intron 7, CpG543 (137872bp from TSS)          exercise
# 45               intron 7, CpG542 (137847bp from TSS)          exercise
# 46               intron 7, CpG543 (137872bp from TSS)          exercise
# 47            intron 7, CpG542+CpG543 (control group)          exercise
# 48                 cg01546433; cg24650785; cg00298481            stress
# 49                 cg04481212; cg01546433; cg00298481          exercise
#
#                                   intervention_detail            tissue  \
# 0   Holocaust exposure (concentration camp torture...             blood
# 1   Intergenerational Holocaust exposure (parental...             blood
# 2   childhood abuse (sexual - physical - neglect) ...             brain
# 3   childhood trauma (sexual - physical - emotiona...             blood
# 4   childhood trauma (physical - emotional - sexua...             blood
# 5   childhood trauma (physical - emotional - sexua...             blood
# 6   childhood trauma (CTQ) in PTSD patients and he...             blood
# 7   lifetime trauma exposure + current PTSD sympto...  placental tissue
# 8   lifetime trauma exposure + current PTSD sympto...  placental tissue
# 9   chronic social stress: being bullied (self-rep...            saliva
# 10  chronic social stress: lack of friends in scho...            saliva
# 11  maternal perceived stress during pregnancy (co...             blood
# 12  maternal perceived stress during pregnancy (PS...             blood
# 13  transgenerational trauma exposure - 3rd/4th-ge...            saliva
# 14  transgenerational trauma exposure - 3rd/4th-ge...            saliva
# 15  maternal hair cortisol concentration, 30 weeks...            saliva
# 16  maternal hair cortisol concentration, 30 weeks...            saliva
# 17  14-week combined training (aerobic+resistance)...             blood
# 18  14-week combined training (aerobic+resistance)...             blood
# 19  14-week combined training (aerobic+resistance)...             blood
# 20  6-month aerobic exercise RCT (postmenopausal w...             blood
# 21  6-month aerobic exercise RCT (postmenopausal w...             blood
# 22  6-month aerobic exercise RCT (postmenopausal w...             blood
# 23  6-month aerobic exercise RCT (postmenopausal w...             blood
# 24  everyday discrimination exposure (EDS), pregna...             blood
# 25  everyday discrimination exposure (EDS), pregna...             blood
# 26  everyday discrimination exposure (EDS), pregna...             blood
# 27  childhood exposure to domestic violence / IPV-...            saliva
# 28  Self-reported chronic stress and exposure to v...            saliva
# 29  Self-reported chronic stress and exposure to v...            saliva
# 30  NICU early life stress (acute stress event fre...            buccal
# 31  INTERGENERATIONAL: maternal (mostly) Holocaust...             blood
# 32  childhood maltreatment (substantiated, moderat...            saliva
# 33  childhood maltreatment measured by continuous ...             blood
# 34  retrospective self-report of childhood physica...             blood
# 35  chronic work-related stress/burnout (clinicall...             blood
# 36  chronic work-related stress/burnout (clinicall...             blood
# 37  Psychotherapy for PTSD (in-patient trauma-focu...             blood
# 38  Psychotherapy for PTSD (in-patient trauma-focu...             blood
# 39  Regular exercise (>=3x/week, >=30min/session) ...             blood
# 40  Regular exercise (>=3x/week, >=30min/session) ...             blood
# 41  Regular exercise (>=3x/week, >=30min/session) ...             blood
# 42  Regular exercise (>=3x/week, >=30min/session) ...             blood
# 43  12-week supervised aerobic+resistance training...             other
# 44  12-week supervised aerobic+resistance training...             other
# 45  12-week supervised aerobic+resistance training...             other
# 46  12-week supervised aerobic+resistance training...             other
# 47  Sedentary control group, no intervention, 12-w...             other
# 48  combat-related PTSD diagnosis (chronic trauma ...             blood
# 49  self-reported active exercise (>=3x/week) vs i...             blood
#
#                                             cell_type  sample_size_n  \
# 0                                    peripheral blood             32
# 1                                    peripheral blood             22
# 2                            hippocampus (postmortem)             36
# 3                                    peripheral blood             96
# 4                         peripheral blood leukocytes            168
# 5                         peripheral blood leukocytes            168
# 6                                     whole blood DNA            180
# 7   placental tissue (villous, maternal decidua ex...            166
# 8   placental tissue (villous, maternal decidua ex...            156
# 9                                                 NaN           1129
# 10                                                NaN           1135
# 11     cord blood or newborn dried blood spot (mixed)            661
# 12     cord blood or newborn dried blood spot (mixed)            661
# 13                                                NaN            186
# 14                                                NaN            186
# 15                                                NaN             50
# 16                                                NaN             50
# 17                                                NaN             40
# 18                                                NaN             40
# 19                                                NaN             40
# 20                                                NaN            117
# 21                                                NaN            117
# 22                                                NaN            117
# 23                                                NaN            117
# 24                                                NaN            147
# 25                                                NaN            147
# 26                                                NaN            147
# 27                                                NaN             54
# 28                   not specified (whole saliva DNA)             48
# 29                   not specified (whole saliva DNA)             48
# 30                            buccal epithelial cells             10
# 31  whole blood / PBMC (mixed across two sub-cohorts)            187
# 32  saliva DNA (mixture of leukocytes and buccal e...            174
# 33                                        whole blood            203
# 34                         leukocyte (buffy coat DNA)            295
# 35                          whole blood leukocyte DNA            119
# 36                          whole blood leukocyte DNA            119
# 37                                    CD14+ monocytes             53
# 38                                    CD14+ monocytes             57
# 39                 whole blood (unspecified fraction)            998
# 40                 whole blood (unspecified fraction)            105
# 41                 whole blood (unspecified fraction)            998
# 42                 whole blood (unspecified fraction)            105
# 43         gluteal subcutaneous adipose tissue (GSAT)             19
# 44         gluteal subcutaneous adipose tissue (GSAT)             19
# 45       abdominal subcutaneous adipose tissue (ASAT)             19
# 46       abdominal subcutaneous adipose tissue (ASAT)             19
# 47  gluteal + abdominal subcutaneous adipose tissu...             12
# 48                        whole blood (leukocyte DNA)             96
# 49                        whole blood (leukocyte DNA)             96
#
#     direction                                        effect_size  \
# 0       hyper                                               5.06
# 1        hypo                                              -4.45
# 2       hyper                                                NaN
# 3       mixed                                                NaN
# 4       hyper                                                NaN
# 5       hyper                                                NaN
# 6       mixed                                                NaN
# 7       mixed  -T=1.50% T-S=1.43% T+S=2.04% (overall raw meth...
# 8   no_change                                                NaN
# 9       hyper                                                NaN
# 10      hyper                                                NaN
# 11      hyper  0.021% increase per 1-unit increase in PSS T-s...
# 12      mixed                                             613.45
# 13       hypo         median beta 0.53 (non-desc) vs 0.51 (desc)
# 14      hyper           mean beta 0.78 (non-desc) vs 0.80 (desc)
# 15       hypo                                          B=-17.041
# 16       hypo                                          B=-10.461
# 17       hypo                                        beta=-0.029
# 18       hypo                                        beta=-0.022
# 19      hyper                                          beta=0.01
# 20      mixed                                       F(gxt)=8.546
# 21      mixed                                       F(gxt)=4.456
# 22      mixed                                       F(gxt)=7.133
# 23      mixed                                       F(gxt)=7.799
# 24       hypo                                                NaN
# 25       hypo                                                NaN
# 26       hypo                                                NaN
# 27      hyper                                                NaN
# 28       hypo                                             -1.969
# 29  no_change                                                NaN
# 30      hyper                                                NaN
# 31       hypo                                              -2.62
# 32       hypo  -1.32% methylation (CpG1: 88.53%→87.21%; CpG2:...
# 33      mixed  β=-0.063 at CpG chr6:35693881 (nominal effect ...
# 34      hyper                                               2.20
# 35      hyper                                                NaN
# 36       hypo                                                NaN
# 37  no_change                                             -0.019
# 38  no_change                                               0.06
# 39       hypo                                           -0.00195
# 40  no_change                                            0.00312
# 41  no_change                                            0.00042
# 42       hypo                                           -0.00611
# 43      hyper                                                  4
# 44  no_change                                                1.8
# 45      hyper                                                  9
# 46      hyper                                                  9
# 47  no_change                                                NaN
# 48       hypo                                                NaN
# 49       hypo                                                NaN
#
#                                               p_value  \
# 0                                               0.046
# 1                                               0.034
# 2                                                 NaN
# 3                                              0.0005
# 4                                               0.002
# 5                                               0.007
# 6                                              0.0154
# 7                                               0.003
# 8                                                0.05
# 9                                                 NaN
# 10                                                NaN
# 11                                            0.00027
# 12                                              0.024
# 13                                                NaN
# 14                                                NaN
# 15                                               .001
# 16                                               .007
# 17                                               .039
# 18                                               .042
# 19                                               .046
# 20                                               .005
# 21                                               .038
# 22                                               .009
# 23                                               .006
# 24                                              0.004
# 25                                              0.004
# 26                                              0.001
# 27                                              0.003
# 28                                              0.043
# 29                                              0.144
# 30                                              0.004
# 31                                              0.013
# 32                         0.002 (CpG1); 0.023 (CpG2)
# 33  0.049 (nominal, uncorrected; does not survive ...
# 34                                              0.008
# 35                                              0.002
# 36                                              0.004
# 37                                              0.196
# 38                                              0.494
# 39                                             0.0157
# 40                                             0.2207
# 41                                             0.5766
# 42                                             0.0081
# 43                                              0.019
# 44  not significant (exact p not reported, ns per ...
# 45  <0.001 (per figure significance stars, exact v...
# 46  <0.001 (per figure significance stars, exact v...
# 47                    >0.05 (both tissues, both CpGs)
# 48                                           0.000259
# 49                                              0.005
#
#                                                method  \
# 0                                      pyrosequencing
# 1                                      pyrosequencing
# 2                            sodium bisulfite mapping
# 3                         EpiTYPER Sequenom MassArray
# 4                            bisulfite pyrosequencing
# 5                            bisulfite pyrosequencing
# 6                            bisulfite pyrosequencing
# 7                            bisulfite pyrosequencing
# 8                            bisulfite pyrosequencing
# 9                                      pyrosequencing
# 10                                     pyrosequencing
# 11  Illumina 450K/EPIC BeadChip; linear regression...
# 12  Illumina 450K/EPIC BeadChip; SKAT gene-based t...
# 13  Illumina Infinium MethylationEPIC v2 BeadChip;...
# 14  Illumina Infinium MethylationEPIC v2 BeadChip;...
# 15  PyroMark Q24 pyrosequencing; multivariable reg...
# 16  PyroMark Q24 pyrosequencing; multivariable reg...
# 17  Illumina EPIC Infinium Methylation BeadChip; c...
# 18  Illumina EPIC Infinium Methylation BeadChip; c...
# 19  Illumina EPIC Infinium Methylation BeadChip; c...
# 20  Illumina EPIC Infinium Methylation BeadChip; l...
# 21  Illumina EPIC Infinium Methylation BeadChip; l...
# 22  Illumina EPIC Infinium Methylation BeadChip; l...
# 23  Illumina EPIC Infinium Methylation BeadChip; l...
# 24                           bisulfite pyrosequencing
# 25                           bisulfite pyrosequencing
# 26                           bisulfite pyrosequencing
# 27                           bisulfite pyrosequencing
# 28                           Bisulfite pyrosequencing
# 29                           Bisulfite pyrosequencing
# 30             Bisulfite NGS deep amplicon sequencing
# 31                           Bisulfite pyrosequencing
# 32                           bisulfite pyrosequencing
# 33     targeted bisulfite sequencing (Illumina MiSeq)
# 34    Pyrosequencing; multivariable linear regression
# 35  Pyrosequencing; Mann-Whitney U test (Bonferron...
# 36  Pyrosequencing; Mann-Whitney U test (Bonferron...
# 37           targeted deep bisulfite sequencing (DBS)
# 38           targeted deep bisulfite sequencing (DBS)
# 39   Illumina Infinium MethylationEPIC BeadChip array
# 40   Illumina Infinium MethylationEPIC BeadChip array
# 41   Illumina Infinium MethylationEPIC BeadChip array
# 42   Illumina Infinium MethylationEPIC BeadChip array
# 43                           bisulfite pyrosequencing
# 44                           bisulfite pyrosequencing
# 45                           bisulfite pyrosequencing
# 46                           bisulfite pyrosequencing
# 47                           bisulfite pyrosequencing
# 48  Illumina Infinium EPIC array; bisulfite conver...
# 49  Illumina Infinium EPIC array; bisulfite conver...
#
#                                         quality_notes  \
# 0   Small sample (n=32 exposed). Cross-sectional. ...
# 1   Small sample (n=22 offspring). Intergeneration...
# 2   Postmortem tissue - no live subjects. Three-gr...
# 3   Longitudinal (baseline/3m/6m post-rape). Direc...
# 4   MZ twin pairs design. Multiple CpGs - hypermet...
# 5   MZ twin pairs design. Multiple CpGs - hypermet...
# 6   No main effect of trauma exposure on BDNF meth...
# 7   T+S group showed higher methylation than -T at...
# 8   No significant differences between trauma grou...
# 9   Cross-sectional; OR=1.89 (95%CI 1.08-3.32) for...
# 10  Cross-sectional; OR=2.30 (95%CI 1.09-4.86) for...
# 11  Significant after Bonferroni correction (thres...
# 12  TRANSGENERATIONAL design (exposure=mother; out...
# 13  Bayesian analysis - no classical p-value; 95% ...
# 14  Bayesian analysis - no classical p-value; 95% ...
# 15  NOTE: transgenerational design - exposure (hai...
# 16  NOTE: transgenerational design - exposure (hai...
# 17  desenho pre-post sem grupo controlo separado (...
# 18  desenho pre-post sem grupo controlo separado (...
# 19  desenho pre-post sem grupo controlo separado (...
# 20  apenas efeito group-by-time reportado (F=8.546...
# 21  apenas efeito group-by-time reportado (F=4.456...
# 22  apenas efeito group-by-time reportado (F=7.133...
# 23  apenas efeito group-by-time reportado (F=7.799...
# 24  RR from ZIP regression not % methylation diff;...
# 25  CpG6 RR=0.86 p=0.004 (T1), RR=0.89 p=0.025 (T2...
# 26  RR=0.85 p<0.001 at T1; not significant at T2 (...
# 27  rs=0.404 CpG3 x childhood domestic violence, s...
# 28  Male-only subgroup (n=48) significant (beta=-1...
# 29  No significant association with stress (males ...
# 30  Very small pilot study (N=10); exploratory Spe...
# 31  Total sample: offspring n=147 (mean=64.87%) vs...
# 32  Preschool-aged sample (3-5 years); maltreatmen...
# 33  No effect survived correction for multiple tes...
# 34  Novel CpG island shore site downstream of NR3C...
# 35  Cross-sectional case-control design — no causa...
# 36  Cross-sectional case-control design — no causa...
# 37  Intervention is psychotherapy/treatment respon...
# 38  Intervention is psychotherapy/treatment respon...
# 39  CROSS-SECTIONAL design, not pre/post intervent...
# 40  CROSS-SECTIONAL design, not pre/post intervent...
# 41  CROSS-SECTIONAL design, not pre/post intervent...
# 42  CROSS-SECTIONAL design, not pre/post intervent...
# 43  Effect genotype-dependent: significant hyperme...
# 44  Increase not statistically significant in over...
# 45  Both CC and CT genotypes showed hypermethylati...
# 46  Both CC and CT genotypes showed hypermethylati...
# 47  Control comparator for the exercise group abov...
# 48  PTSD (n=48) vs combat-exposed non-PTSD control...
# 49  Cross-sectional, not a longitudinal interventi...
#
#                                doi;
# 0   10.1016/j.biopsych.2015.08.005;
# 1   10.1016/j.biopsych.2015.08.005;
# 2                  10.1038/nn.2270;
# 3     10.1080/20008066.2025.2485707
# 4      10.1097/PSY.0000000000000604
# 5      10.1097/PSY.0000000000000604
# 6         10.1016/j.jad.2022.03.020
# 7     10.1080/10253890.2024.2321595
# 8     10.1080/10253890.2024.2321595
# 9         10.1038/s41398-018-0169-8
# 10        10.1038/s41398-018-0169-8
# 11              10.1093/eep/dvaf024
# 12              10.1093/eep/dvaf024
# 13       10.1038/s41598-025-12085-5
# 14       10.1038/s41598-025-12085-5
# 15                10.1002/dev.22352
# 16                10.1002/dev.22352
# 17      10.1016/j.exger.2024.112362
# 18      10.1016/j.exger.2024.112362
# 19      10.1016/j.exger.2024.112362
# 20       10.1007/s11357-025-02004-x
# 21       10.1007/s11357-025-02004-x
# 22       10.1007/s11357-025-02004-x
# 23       10.1007/s11357-025-02004-x
# 24   10.1016/j.psyneuen.2018.08.014
# 25   10.1016/j.psyneuen.2018.08.014
# 26   10.1016/j.psyneuen.2018.08.014
# 27     10.1371/journal.pone.0143427
# 28     10.1371/journal.pone.0273717
# 29     10.1371/journal.pone.0273717
# 30     10.1097/ANC.0000000000001208
# 31   10.1176/appi.ajp.2019.19060618
# 32        10.1017/S0954579415000991
# 33             10.3390/ijms25031485
# 34            10.2217/epi-2016-0074
# 35        10.1016/j.jad.2021.08.081
# 36        10.1016/j.jad.2021.08.081
# 37       10.1038/s41598-022-22177-1
# 38       10.1038/s41598-022-22177-1
# 39              10.1155/jdr/1162708
# 40              10.1155/jdr/1162708
# 41              10.1155/jdr/1162708
# 42              10.1155/jdr/1162708
# 43       10.1038/s41598-022-15678-6
# 44       10.1038/s41598-022-15678-6
# 45       10.1038/s41598-022-15678-6
# 46       10.1038/s41598-022-15678-6
# 47       10.1038/s41598-022-15678-6
# 48       10.1016/j.gene.2019.02.067
# 49       10.1016/j.gene.2019.02.067
